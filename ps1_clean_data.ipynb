# %%
import pandas

# %%
df = pandas.read_csv("ps1_nipa_unformatted.csv", header=None)
df
# Out:
#      0                                                  1       2       3    \
# 0   Line                                                NaN    1947    1947
# 1   Line                                                NaN      Q1      Q2
# 2      1                             Gross domestic product  12.552  12.519
# 3      2                  Personal consumption expenditures  11.583  11.776
# 4      3                                              Goods  12.230  12.450
# 5      4                                      Durable goods   3.896   3.978
# 6      5                                   Nondurable goods  20.684  21.038
# 7      6                                           Services  10.450  10.602
# 8      7                  Gross private domestic investment   8.319   7.681
# 9      8                                   Fixed investment   8.923   8.692
# 10     9                                     Nonresidential   6.065   5.971
# ...

# %%
df.iloc[0,:] = df.iloc[0,:] + df.iloc[1,:]

# %%
df = df.drop(1).drop(0,axis=1).transpose()

# %%
df
# Out:
#          0                               2   \
# 1       NaN          Gross domestic product
# 2    1947Q1                          12.552
# 3    1947Q2                          12.519
# 4    1947Q3                          12.493
# 5    1947Q4                          12.688
# ..      ...                             ...
# 293  2019Q4                         118.874
# 294  2020Q1                         117.373
# 295  2020Q2                         106.825
# 296  2020Q3                         114.815
# 297  2020Q4                         115.949
#
#                                     3          4                      5   \
# 1    Personal consumption expenditures      Goods          Durable goods
# 2                               11.583     12.230                  3.896
# 3                               11.776     12.450                  3.978
# 4                               11.814     12.533                  4.033
# ...

# %%
df = df.iloc[1:,[1,2,7,8,9,10,11,12,13]]

# %%
df = df.rename(columns={2:"gdp",3:"c",8:"investment",9:"fixed_i",10:"nonresidential",11:"structures",12:"equipment",13:"intellectual",14:"residential"})

# %%
df = df.replace(to_replace="---",value="")

# %%
df.to_csv("ps1_data.csv", index=False)

# %%
df = df.astype(float)

# %%
import numpy as np

# %%
df.apply(np.log)
# Out:
#           gdp         c  investment   fixed_i  nonresidential  structures  \
# 2    2.529880  2.449539    2.118542  2.188632        1.802535    3.351937
# 3    2.527247  2.466064    2.038750  2.162403        1.786914    3.346636
# 4    2.525168  2.469285    2.008885  2.194220        1.768320    3.353407
# 5    2.540657  2.469624    2.185827  2.273259        1.795751    3.338932
# 6    2.555598  2.474604    2.283504  2.304783        1.852227    3.359472
# ..        ...       ...         ...       ...             ...         ...
# 293  4.778064  4.798448    4.869010  4.888859        4.877431    4.733599
# 294  4.765357  4.780669    4.845485  4.885382        4.860146    4.724153
# 295  4.671192  4.679851    4.688573  4.799083        4.780903    4.621840
# 296  4.743322  4.765800    4.844187  4.867242        4.832401    4.573927
# 297  4.753150  4.771972    4.900605  4.909495        4.864669    4.581328
#
#      equipment  intellectual  residential
# ...

# %%
# Out:
# gdp               0
# c                 0
# investment        0
# fixed_i           0
# nonresidential    0
# structures        0
# equipment         0
# intellectual      0
# residential       0
# dtype: int64
